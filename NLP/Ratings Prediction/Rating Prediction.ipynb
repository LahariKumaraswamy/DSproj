# %%
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
laptop=pd.read_csv("Laptop.csv")

# %%
watch=pd.read_csv("SmartWatches.csv")

# %%
camera=pd.read_csv("Camera.csv")

# %%
monitor=pd.read_csv("Monitor.csv")

# %%
headphones=pd.read_csv("Headphone.csv")

# %%
hometheatre=pd.read_csv("HomeTheatre.csv")

# %%
printer=pd.read_csv("printer.csv")

# %%
router=pd.read_csv("router.csv")

# %%
mobile=pd.read_csv("mobile.csv")

# %%
data=laptop.append([watch,camera,monitor,headphones,hometheatre,printer,router,mobile])

# %%
data["Rating"].value_counts()
# Out:
# 5    59278
# 4    18844
# 1     7481
# 3     5978
# 2     2728
# Name: Rating, dtype: int64

# %%
data= data.sample(frac = 1)

# %%
data
# Out:
#        Unnamed: 0  Rating                  Review  \
# 4592         1302       5               Fabulous!
# 13077          40       5               Just wow!
# 9973         2874       5        Perfect product!
# 6223         5713       5        Perfect product!
# 4917         4917       3               Just okay
# ...           ...     ...                     ...
# 10912         513       5               Brilliant
# 3977          687       5               Just wow!
# 1900         1900       5               Hated it!
# 4875         4875       4  Worst experience ever!
# 1552         1552       4           Great product
#
#                                              Description
# 4592                             Overall a great product
# 13077  Nice product with awesome design and performan...
# 9973                                     Valuable Mobile
# 6223   Flipkart is a genuine product online shopping ...
# 4917                                                good
# ...

# %%
data
# Out:
#        Unnamed: 0  Rating                  Review  \
# 4592         1302       5               Fabulous!
# 13077          40       5               Just wow!
# 9973         2874       5        Perfect product!
# 6223         5713       5        Perfect product!
# 4917         4917       3               Just okay
# ...           ...     ...                     ...
# 10912         513       5               Brilliant
# 3977          687       5               Just wow!
# 1900         1900       5               Hated it!
# 4875         4875       4  Worst experience ever!
# 1552         1552       4           Great product
#
#                                              Description
# 4592                             Overall a great product
# 13077  Nice product with awesome design and performan...
# 9973                                     Valuable Mobile
# 6223   Flipkart is a genuine product online shopping ...
# 4917                                                good
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0     0
# Rating         0
# Review         1
# Description    0
# dtype: int64

# %%
data = data.dropna(how='any',axis=0)

# %%
data
# Out:
#        Unnamed: 0  Rating                  Review  \
# 4592         1302       5               Fabulous!
# 13077          40       5               Just wow!
# 9973         2874       5        Perfect product!
# 6223         5713       5        Perfect product!
# 4917         4917       3               Just okay
# ...           ...     ...                     ...
# 10912         513       5               Brilliant
# 3977          687       5               Just wow!
# 1900         1900       5               Hated it!
# 4875         4875       4  Worst experience ever!
# 1552         1552       4           Great product
#
#                                              Description
# 4592                             Overall a great product
# 13077  Nice product with awesome design and performan...
# 9973                                     Valuable Mobile
# 6223   Flipkart is a genuine product online shopping ...
# 4917                                                good
# ...

# %%
print('5 random reviews with the highest positive sentiment polarity: \n')
cl = data.loc[data.Rating== 5, ['Description']].sample(5).values
for c in cl:
    print(c[0])
# Out:
# 5 random reviews with the highest positive sentiment polarity:
#
# no bass
# Bass is average there is no bass control
# Suparb
# Nyc quality
# Nice product with awesome design and performance
# Nice battery backup

# %%
print('5 random reviews with the intermediate  sentiment polarity: \n')
cl = data.loc[data.Rating== 3, ['Description']].sample(5).values
for c in cl:
    print(c[0])
# Out:
# 5 random reviews with the intermediate  sentiment polarity:
#
# Good
# Product is good but filipkart delivery was so delayed it took 10 days to deliver the product
# Very bad products
# I did not like the sound of headphones.. Sound is itchy.. It could have been better
#
# My ear starts paining after 15-20 min of use.. But overall I am not returning product as I do not have any other product in similar price range.
# Not happy with lens

# %%
print('5 random reviews with the negative sentiment polarity: \n')
cl = data.loc[data.Rating== 1, ['Description']].sample(5).values
for c in cl:
    print(c[0])
# Out:
# 5 random reviews with the negative sentiment polarity:
#
# Great at this price
# Good
# Oseum product love it
# Product is not charging
# Charging issue
# Good service..great deal..thank u flipkart

# %% [markdown]
# # Rating 5

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
Rating5= data['Review'][data['Rating']==5]
Rating5_cloud = WordCloud(width=600,height=400,background_color='black',max_words=50).generate(' '.join(Rating5))
plt.figure(figsize=(10,8),facecolor='k')
plt.imshow(Rating5_cloud)
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# # Rating 4

# %%
Rating4= data['Review'][data['Rating']==4]
Rating4_cloud = WordCloud(width=600,height=400,background_color='black',max_words=50).generate(' '.join(Rating4))
plt.figure(figsize=(10,8),facecolor='k')
plt.imshow(Rating4_cloud)
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# # Rating 3

# %%
Rating3= data['Review'][data['Rating']==3]
Rating3_cloud = WordCloud(width=600,height=400,background_color='black',max_words=50).generate(' '.join(Rating3))
plt.figure(figsize=(10,8),facecolor='k')
plt.imshow(Rating3_cloud)
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# # Rating 2

# %%
Rating2= data['Review'][data['Rating']==2]
Rating2_cloud = WordCloud(width=600,height=400,background_color='black',max_words=50).generate(' '.join(Rating2))
plt.figure(figsize=(10,8),facecolor='k')
plt.imshow(Rating2_cloud)
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# # Rating 1

# %%
Rating1= data['Review'][data['Rating']==1]
Rating1_cloud = WordCloud(width=600,height=400,background_color='black',max_words=50).generate(' '.join(Rating1))
plt.figure(figsize=(10,8),facecolor='k')
plt.imshow(Rating1_cloud)
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
data
# Out:
#        Unnamed: 0  Rating                  Review  \
# 4592         1302       5               Fabulous!
# 13077          40       5               Just wow!
# 9973         2874       5        Perfect product!
# 6223         5713       5        Perfect product!
# 4917         4917       3               Just okay
# ...           ...     ...                     ...
# 10912         513       5               Brilliant
# 3977          687       5               Just wow!
# 1900         1900       5               Hated it!
# 4875         4875       4  Worst experience ever!
# 1552         1552       4           Great product
#
#                                              Description
# 4592                             Overall a great product
# 13077  Nice product with awesome design and performan...
# 9973                                     Valuable Mobile
# 6223   Flipkart is a genuine product online shopping ...
# 4917                                                good
# ...

# %%
data.drop(["Unnamed: 0","Review"],axis=1,inplace=True)

# %%
data
# Out:
#        Rating                                        Description
# 4592        5                            Overall a great product
# 13077       5  Nice product with awesome design and performan...
# 9973        5                                    Valuable Mobile
# 6223        5  Flipkart is a genuine product online shopping ...
# 4917        3                                               good
# ...       ...                                                ...
# 10912       5                                   Fantastic camera
# 3977        5                 Awesome quality ❤️. Full satisfied
# 1900        5     Material is very bad\nIn 2 month plastic break
# 4875        4  ordered twice as first ones bass automatically...
# 1552        4                                               Nice
#
# [94308 rows x 2 columns]

# %% [markdown]
# # LowerCasing

# %%
data["Description"]=data["Description"].str.lower()

# %% [markdown]
# # Removing Punctuation

# %%
import string
PUNCT_TO_REMOVE = string.punctuation

def remove_punctuation(text):
    return text.translate(str.maketrans('', '', PUNCT_TO_REMOVE))

# %%
data["Description"]=data["Description"].apply(lambda text: remove_punctuation(text))

# %% [markdown]
# # Removing  stopwords

# %%
import nltk
from nltk.corpus import stopwords

STOPWORDS =stopwords.words("english")

for x in range(ord('b'), ord('z')+1):
    STOPWORDS.append(chr(x))

# %%
def remove_stopwords(text):
    return " ".join([word for word in str(text).split() if word not in STOPWORDS])

# %%
data["Description"]=data["Description"].apply(lambda text: remove_stopwords(text))

# %% [markdown]
# # Frequent  Words

# %%
from collections import Counter
cnt = Counter()
for text in data["Description"].values:
    for word in text.split():
        cnt[word] += 1
cnt.most_common(10)
# Out:
# [('good', 38370),
#  ('product', 24339),
#  ('nice', 16057),
#  ('best', 9799),
#  ('price', 9336),
#  ('quality', 9069),
#  ('camera', 8099),
#  ('awesome', 7740),
#  ('phone', 7115),
#  ('battery', 6940)]

# %% [markdown]
# # Lemmatization

# %%
import nltk
from nltk.stem import PorterStemmer, WordNetLemmatizer
#create objects for stemmer and lemmatizer
lemmatiser = WordNetLemmatizer()
stemmer = PorterStemmer()
#download words from wordnet library
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to C:\Users\THIS
# [nltk_data]     PC\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
wordnet_map = {"N":wordnet.NOUN, "V":wordnet.VERB, "J":wordnet.ADJ, "R":wordnet.ADV}
def lemmatize_words(text):
    pos_tagged_text = nltk.pos_tag(text.split())
    return " ".join([lemmatizer.lemmatize(word, wordnet_map.get(pos[0], wordnet.NOUN)) for word, pos in pos_tagged_text])

# %%
data["Description"]=data["Description"].apply(lambda text: lemmatize_words(text))

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split

text = data['Description']
label = data['Rating']

## Converting data to numpy array
## for ease of analysis

text = np.array(text)
label = np.array(label)

label = label - 1

# %%
x_train, x_test, y_train, y_test = train_test_split(text, label, test_size = 0.1, random_state = 42)

tokenizer = Tokenizer(num_words = 25000)
tokenizer.fit_on_texts(x_train)
x_train = tokenizer.texts_to_sequences(x_train)
x_test = tokenizer.texts_to_sequences(x_test)
x_train = pad_sequences(x_train, maxlen = 50)
x_test = pad_sequences(x_test, maxlen = 50)
len(tokenizer.word_index)
# Out:
# 22024

# %%
Mymodel = tf.keras.models.Sequential([
    
    tf.keras.layers.Input(shape = (50,)),
    tf.keras.layers.Embedding(22025, 20),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(70, return_sequences = True)),
    tf.keras.layers.LSTM(140),
    tf.keras.layers.Dense(5, activation = 'softmax')
])

Mymodel.compile(optimizer = 'Adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'] )

# %%
retVal = Mymodel.fit(x_train, y_train,epochs = 20 )
# Out:
# Epoch 1/20
# 2653/2653 [==============================] - 226s 83ms/step - loss: 1.0464 - accuracy: 0.6376
# Epoch 2/20
# 2653/2653 [==============================] - 253s 95ms/step - loss: 0.9539 - accuracy: 0.6584
# Epoch 3/20
# 2653/2653 [==============================] - 260s 98ms/step - loss: 0.8832 - accuracy: 0.6880
# Epoch 4/20
# 2653/2653 [==============================] - 262s 99ms/step - loss: 0.8333 - accuracy: 0.7109
# Epoch 5/20
# 2653/2653 [==============================] - 259s 98ms/step - loss: 0.7870 - accuracy: 0.7251
# Epoch 6/20
# 2653/2653 [==============================] - 259s 98ms/step - loss: 0.7570 - accuracy: 0.7354
# Epoch 7/20
# 2653/2653 [==============================] - 260s 98ms/step - loss: 0.7243 - accuracy: 0.7461
# Epoch 8/20
# 2653/2653 [==============================] - 262s 99ms/step - loss: 0.7095 - accuracy: 0.7504
# Epoch 9/20
# 2653/2653 [==============================] - 269s 101ms/step - loss: 0.6914 - accuracy: 0.7554
# Epoch 10/20
# ...

# %%
Mymodel.evaluate(x_test,y_test)
# Out:
# 295/295 [==============================] - 9s 25ms/step - loss: 1.4870 - accuracy: 0.6495
# [1.4869600534439087, 0.6494539380073547]

# %% [markdown]
# # End Of Document
